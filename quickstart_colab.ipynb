# %% [markdown]
# <a href="https://colab.research.google.com/github/bionboy/GANSketching/blob/main/QuickStart_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %%bash
# pip install gpp ninja
# pip install clean-fid
# pip install wandb
# pip install lpips
# pip install dominate

# %%
pip install Pillow==7.1.0

# %%
pip uninstall Pillow-y

# %%
# %%bash
# cd /content/drive/Shareddrives/wcz05222@gmail.com/CHIA_CHI_deep_learning/GANSketching-main
# python train.py --name animate --size 256 \
# --batch 1 --dataroot_sketch /content/drive/Shareddrives/wcz05222@gmail.com/CHIA_CHI_deep_learning/GANSketching-main/data/sketch/by_author/animate \
# --dataroot_image /content/drive/Shareddrives/wcz05222@gmail.com/CHIA_CHI_deep_learning/GANSketching-main/data/image/animate_png --l_image 0.7 --d_pretrained /content/drive/Shareddrives/wcz05222@gmail.com/CHIA_CHI_deep_learning/GANSketching-main/pretrained/d_net.pth --g_pretrained /content/drive/Shareddrives/wcz05222@gmail.com/CHIA_CHI_deep_learning/GANSketching-main/pretrained/g_net.pth --max_iter 10 --disable_eval --diffaug_policy translation --no_wandb

# %%
# %%bash
# cd /content/drive/Shareddrives/wcz05222@gmail.com/CHIA_CHI_deep_learning/GANSketching-main
# python generate.py --ckpt /content/drive/Shareddrives/wcz05222@gmail.com/CHIA_CHI_deep_learning/GANSketching-main/checkpoint/animate/0_net_G.pth --save_dir output/anime_generate --samples 1

# %%
# %%bash
# cd GANSketching/
# python ganspace.py --obj anime --comp_id 45 --scalar 60 --layers 5,7 --ckpt /content/drive/Shareddrives/wcz05222@gmail.com/CHIA_CHI_deep_learning/GANSketching-main/checkpoint/animate/0_net_G.pth --save_dir output/anime_ganspace

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import shutil
import sys
import os
from glob import glob

# %%
path = glob('./data/image/animate_png/*')

# %%
dd=0
path1=[]
for i in path:
  if dd==90:
    break
  path1.append(i)
  dd+=1

# %%
len(path1)

# %%
path1[1]

# %%
for i in path1:
  shutil.move(i, "/content/drive/Shareddrives/wcz05222@gmail.com/CHIA_CHI_deep_learning/GANSketching-main/data/image/animate2")

# %%
len(path)
